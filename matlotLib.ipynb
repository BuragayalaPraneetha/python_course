# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
import numpy as np

x = np.arange(0, 10)
y = np.arange(11, 21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##plotting using matplotlib 

##plt scatter

# %%
plt.scatter(x,y,c='g')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.tittle("graph in 2D")
plt.savifig("Test.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 4
#       2 plt.xlabel("X axis")
#       3 plt.ylabel("Y axis")
# ----> 4 plt.tittle("graph in 2D")
#       5 plt.savifig("Test.png")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
y=x*x

# %%
#plt plot
plt.plot(x,y,'y')

# %%
#creating subplots
x= np.arange(1,11)
y= 5* x 
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")
plt.ylabel("y axis")
plt.plot(x,y)
plt.show()

# %%
#bar plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 
plt.bar(x, y) 
plt.bar(x2, y2, color = 'b') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis')
# Out:
# Text(0.5, 0, 'X axis')

# %%
#histograms

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a)
plt.title("histogram")
plt.show()

# %%
#box plot using Matplotlib

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]
#rectangular box plot
plt.boxplot(data,vert= True,patch_artist= True);
